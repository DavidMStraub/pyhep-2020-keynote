# %%
import requests

# %%
requests.get(f"https://inspirehep.net/api/literature?size=1&q=texkey:Aebischer:2019mlg")
# Out:
# <Response [200]>

# %%
res=_

# %%
_.json()
# Out:
# {'hits': {'hits': [{'updated': '2020-07-08T15:45:36.027648+00:00',
#     'metadata': {'citation_count': 119,
#      'documents': [{'key': '65f5a4aa0d63b5a025ac12f5af583b82',
#        'url': 'https://inspirehep.net/files/65f5a4aa0d63b5a025ac12f5af583b82',
#        'filename': '10.1140_epjc_s10052-020-7817-x.pdf',
#        'description': 'Fulltext from Publisher'},
#       {'key': '666b5aab407ea2f5fbe2aa3d159862e7',
#        'url': 'https://inspirehep.net/files/666b5aab407ea2f5fbe2aa3d159862e7',
#        'source': 'SCOAP3',
#        'filename': 'scoap3-fulltext.pdf;pdfa',
#        'description': 'Article from SCOAP3'}],
#      'citation_count_without_self_citations': 107,
#      'publication_info': [{'year': 2020,
#        'artid': '252',
#        'page_start': '252',
#        'journal_issue': '3',
#        'journal_title': 'Eur.Phys.J.C',
#        'journal_volume': '80'}],
#      'author_count': 6,
#      'earliest_date': '2019-03-25',
# ...
